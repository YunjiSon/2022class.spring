# %% [markdown]
# <a href="https://colab.research.google.com/github/YunjiSon/2022spring/blob/main/pytorch_hub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# image generation (ex. PGAN)

# %%
import torch
model = torch.hub.load('facebookresearch/pytorch_GAN_zoo:hub', 'PGAN', model_name='celebAHQ-512', pretrained=True)
#이렇게 하면 PGAN 알고리즘 모델 가져옴.
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorch_GAN_zoo_hub
# Average network found !

# %%
num_images = 4
noise, _ = model.buildNoiseData(num_images)
with torch.no_grad():
    generated_images = model.test(noise)
    #원래 모델이 이렇게 학습됨. random한 것을 만들어내는 것. 

# let's plot these images using torchvision and matplotlib
import matplotlib.pyplot as plt
import torchvision
grid = torchvision.utils.make_grid(generated_images.clamp(min=-1, max=1), scale_each=True, normalize=True)
plt.imshow(grid.permute(1, 2, 0).cpu().numpy())
#셀러브리티 느낌의 사진을 만들어냄.
